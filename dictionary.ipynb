# %%
import pandas as pd

# %%
df=pd.read_csv("dataset/dictionary.csv")

# %%
df[0:40]
# Out:
#                            word  \
# 0     abandoned industrial site
# 1             abandoned vehicle
# 2                abiotic factor
# 3                   access road
# 4             access to the sea
# 5                      accident
# 6                   accumulator
# 7                 acidification
# 8                       acidity
# 9                acidity degree
# 10                    acid rain
# 11                         acid
# 12              acoustic filter
# 13          acoustic insulation
# 14               acoustic level
# 15            acoustic property
# 16                    acoustics
# 17                     actinide
# 18                     actinium
# 19                 action group
# 20             activated carbon
# 21             activated sludge
# 22                          act
# 23            adaptable species
# 24            chemical addition
# 25         additional packaging
# 26             addition polymer
# 27                     additive
# ...

# %%
df.loc[df['word']=='abiotic factor']['definition'].squeeze()
# Out:
# 'Physical, chemical and other non-living environmental factor.'

# %%
df.loc[df['word']=='sun']['definition'].squeeze()
# Out:
# '1. Any star, especially when seen as the centre of any single solar system.\n2. The particular star at the centre of our solar system, from which the Earth gets light and heat.\n'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49537 entries, 0 to 49536
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   word        49536 non-null  object
#  1   definition  49537 non-null  object
# dtypes: object(2)
# memory usage: 774.1+ KB

# %%
df.loc[df['word']=='sun']
# Out:
#      word                                         definition
# 3449  sun  1. Any star, especially when seen as the centr...

# %%
df.loc[df['word']=='rajaa']
# Out:
# Empty DataFrame
# Columns: [word, definition]
# Index: []

# %%
df.loc[df['word']=='economy']
# Out:
#         word                                         definition
# 712  economy  The system of activities and administration th...

# %%
df['word'][100:150]
# Out:
# 100                   allergy
# 101                allocation
# 102                     alloy
# 103                  alluvion
# 104           alpha radiation
# 105    alternative technology
# 106                   alumina
# 107                  alveolus
# 108                   amalgam
# 109                  Americas
# 110                 Ames test
# 111                     amine
# 112                amino acid
# 113                   ammonia
# 114            ammonification
# 115                  ammonium
# 116                 amphibian
# 117            amusement park
# 118                  analysis
# 119      analytical chemistry
# 120         analytical method
# 121                   anatomy
# 122                angiosperm
# 123                   angling
# 124            animal disease
# 125            animal ecology
# 126         animal experiment
# 127           animal genetics
# 128            animal housing
# 129          animal husbandry
# 130             animal manure
# ...

# %%
df.loc[df['word']=='Antartica']
# Out:
#             word                      definition
# 28023  Antartica  The area round the South Pole.

# %%
if  df.loc[df['word']=='antartica'].empty:
    print("A")
else:
    print("B")
# Out:
# A

# %%
df
# Out:
#                             word  \
# 0      abandoned industrial site
# 1              abandoned vehicle
# 2                 abiotic factor
# 3                    access road
# 4              access to the sea
# ...                          ...
# 49532                     casing
# 49533                     facing
# 49534                     lining
# 49535         assumption of Mary
# 49536               auscultation
#
#                                               definition
# 0      Site that cannot be used for any purpose, bein...
# 1      A vehicle that has been discarded in the envir...
# 2      Physical, chemical and other non-living enviro...
# 3      Any street or narrow stretch of paved surface ...
# 4      The ability to bring goods to and from a port ...
# ...                                                  ...
# 49532  Something put around something else, usually i...
# 49533  Something put around something else, usually i...
# ...
