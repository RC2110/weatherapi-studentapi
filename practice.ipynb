# %% [markdown]
# ## Loading the data

# %%
import pandas as pd

# %%
df= pd.read_csv("dataset/TG_STAID000001.txt", skiprows=20, parse_dates=['    DATE'])

# %%
df['    DATE'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df[[' SOUID','    DATE', '   TG']]
# Out:
#         SOUID       DATE     TG
# 0       35381 1860-01-01     21
# 1       35381 1860-01-02     46
# 2       35381 1860-01-03     31
# 3       35381 1860-01-04     37
# 4       35381 1860-01-05     31
# ...       ...        ...    ...
# 59316   35381 2022-05-27  -9999
# 59317   35381 2022-05-28  -9999
# 59318   35381 2022-05-29  -9999
# 59319   35381 2022-05-30  -9999
# 59320   35381 2022-05-31  -9999
#
# [59321 rows x 3 columns]

# %%
df['   TG']
# Out:
# 0          21
# 1          46
# 2          31
# 3          37
# 4          31
#          ...
# 59316   -9999
# 59317   -9999
# 59318   -9999
# 59319   -9999
# 59320   -9999
# Name:    TG, Length: 59321, dtype: int64

# %% [markdown]
# ## performing statistics on the data

# %%
df.loc[df['   TG']!=-9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
df.loc[df['   TG']!=-9999]['   TG'].mean()
# Out:
# 63.607875261284676

# %%
df.loc[df['   TG']!=-9999]['   TG'].min()
# Out:
# -288

# %%
df.loc[df['   TG']!=-9999]['   TG'].max()
# Out:
# 262

# %%
df.loc[df['   TG']!=-9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
import numpy as np
df['TG'] = df['   TG'].mask(df['   TG']==-9999, np.nan)

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG    TG
# 0          1   35381 1860-01-01     21      0  21.0
# 1          1   35381 1860-01-02     46      0  46.0
# 2          1   35381 1860-01-03     31      0  31.0
# 3          1   35381 1860-01-04     37      0  37.0
# 4          1   35381 1860-01-05     31      0  31.0
# ...      ...     ...        ...    ...    ...   ...
# 59316      1   35381 2022-05-27  -9999      9   NaN
# 59317      1   35381 2022-05-28  -9999      9   NaN
# 59318      1   35381 2022-05-29  -9999      9   NaN
# 59319      1   35381 2022-05-30  -9999      9   NaN
# 59320      1   35381 2022-05-31  -9999      9   NaN
#
# [59321 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG', 'TG'], dtype='object')

# %%
df['TG']=df['TG']/10

# %%
df['TG'].hist(bins=20)
# Out:
# <Axes: >

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG
# 0          1   35381 1860-01-01     21      0  2.1
# 1          1   35381 1860-01-02     46      0  4.6
# 2          1   35381 1860-01-03     31      0  3.1
# 3          1   35381 1860-01-04     37      0  3.7
# 4          1   35381 1860-01-05     31      0  3.1
# ...      ...     ...        ...    ...    ...  ...
# 59316      1   35381 2022-05-27  -9999      9  NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN
#
# [59321 rows x 6 columns]

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG
# 0          1   35381 1860-01-01     21      0  2.1
# 1          1   35381 1860-01-02     46      0  4.6
# 2          1   35381 1860-01-03     31      0  3.1
# 3          1   35381 1860-01-04     37      0  3.7
# 4          1   35381 1860-01-05     31      0  3.1
# ...      ...     ...        ...    ...    ...  ...
# 59316      1   35381 2022-05-27  -9999      9  NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN
#
# [59321 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG', 'TG'], dtype='object')

# %%
df.loc[df['    DATE']=="2022-05-29"]['TG'].squeeze()
# Out:
# nan

# %%
df.loc[df['    DATE']=="1860-01-04"]['TG'].squeeze()
# Out:
# 3.7

# %%
ls=df.loc[df['TG']==2.7]['    DATE']

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG', 'TG'], dtype='object')

# %%
df.plot('    DATE', 'TG', figsize=(13,3))
# Out:
# <Axes: xlabel='    DATE'>

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG
# 0          1   35381 1860-01-01     21      0  2.1
# 1          1   35381 1860-01-02     46      0  4.6
# 2          1   35381 1860-01-03     31      0  3.1
# 3          1   35381 1860-01-04     37      0  3.7
# 4          1   35381 1860-01-05     31      0  3.1
# ...      ...     ...        ...    ...    ...  ...
# 59316      1   35381 2022-05-27  -9999      9  NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN
#
# [59321 rows x 6 columns]

# %%
df['TG']
# Out:
# 0        2.1
# 1        4.6
# 2        3.1
# 3        3.7
# 4        3.1
#         ...
# 59316    NaN
# 59317    NaN
# 59318    NaN
# 59319    NaN
# 59320    NaN
# Name: TG, Length: 59321, dtype: float64

# %%
df['Farenheit']= df['TG'] * 5/9 +32

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  Farenheit
# 0          1   35381 1860-01-01     21      0  2.1  33.166667
# 1          1   35381 1860-01-02     46      0  4.6  34.555556
# 2          1   35381 1860-01-03     31      0  3.1  33.722222
# 3          1   35381 1860-01-04     37      0  3.7  34.055556
# 4          1   35381 1860-01-05     31      0  3.1  33.722222
# ...      ...     ...        ...    ...    ...  ...        ...
# 59316      1   35381 2022-05-27  -9999      9  NaN        NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN        NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN        NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN        NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN        NaN
#
# [59321 rows x 7 columns]

# %%
df[0:25]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG   TG  Farenheit
# 0       1   35381 1860-01-01     21      0  2.1  33.166667
# 1       1   35381 1860-01-02     46      0  4.6  34.555556
# 2       1   35381 1860-01-03     31      0  3.1  33.722222
# 3       1   35381 1860-01-04     37      0  3.7  34.055556
# 4       1   35381 1860-01-05     31      0  3.1  33.722222
# 5       1   35381 1860-01-06     16      0  1.6  32.888889
# 6       1   35381 1860-01-07      5      0  0.5  32.277778
# 7       1   35381 1860-01-08    -27      0 -2.7  30.500000
# 8       1   35381 1860-01-09     -4      0 -0.4  31.777778
# 9       1   35381 1860-01-10    -17      0 -1.7  31.055556
# 10      1   35381 1860-01-11     -5      0 -0.5  31.722222
# 11      1   35381 1860-01-12    -18      0 -1.8  31.000000
# 12      1   35381 1860-01-13    -27      0 -2.7  30.500000
# 13      1   35381 1860-01-14    -26      0 -2.6  30.555556
# 14      1   35381 1860-01-15    -37      0 -3.7  29.944444
# ...

# %%
df.loc[df['TG']==2.7][0:10]
# Out:
#       STAID   SOUID       DATE     TG   Q_TG   TG  Farenheit
# 279       1   35381 1860-10-06     27      0  2.7       33.5
# 283       1   35381 1860-10-10     27      0  2.7       33.5
# 305       1   35381 1860-11-01     27      0  2.7       33.5
# 418       1   35381 1861-02-22     27      0  2.7       33.5
# 503       1   35381 1861-05-18     27      0  2.7       33.5
# 796       1   35381 1862-03-07     27      0  2.7       33.5
# 1094      1   35381 1862-12-30     27      0  2.7       33.5
# 1098      1   35381 1863-01-03     27      0  2.7       33.5
# 1151      1   35381 1863-02-25     27      0  2.7       33.5
# 1176      1   35381 1863-03-22     27      0  2.7       33.5

# %%
df.loc[df['TG']==2.7]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  Farenheit
# 279        1   35381 1860-10-06     27      0  2.7       33.5
# 283        1   35381 1860-10-10     27      0  2.7       33.5
# 305        1   35381 1860-11-01     27      0  2.7       33.5
# 418        1   35381 1861-02-22     27      0  2.7       33.5
# 503        1   35381 1861-05-18     27      0  2.7       33.5
# ...      ...     ...        ...    ...    ...  ...        ...
# 52910      1   35381 2004-11-11     27      0  2.7       33.5
# 52933      1   35381 2004-12-04     27      0  2.7       33.5
# 53060      1   35381 2005-04-10     27      0  2.7       33.5
# 53070      1   35381 2005-04-20     27      0  2.7       33.5
# 53337      1   35381 2006-01-12     27      0  2.7       33.5
#
# [284 rows x 7 columns]

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  Farenheit
# 0          1   35381 1860-01-01     21      0  2.1  33.166667
# 1          1   35381 1860-01-02     46      0  4.6  34.555556
# 2          1   35381 1860-01-03     31      0  3.1  33.722222
# 3          1   35381 1860-01-04     37      0  3.7  34.055556
# 4          1   35381 1860-01-05     31      0  3.1  33.722222
# ...      ...     ...        ...    ...    ...  ...        ...
# 59316      1   35381 2022-05-27  -9999      9  NaN        NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN        NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN        NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN        NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN        NaN
#
# [59321 rows x 7 columns]

# %%
df.loc[df['TG']==df['TG'].max()]['TG'].squeeze()
# Out:
# 26.2

# %%
df.loc[df['TG']==df['TG'].max()]['    DATE'].squeeze()
# Out:
# Timestamp('1868-08-16 00:00:00')

# %%
df[100:1000].plot('    DATE', 'TG', figsize=(13,3))
# Out:
# <Axes: xlabel='    DATE'>
