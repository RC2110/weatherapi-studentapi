# %% [markdown]
# ## Loading the data

# %%
pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/40/d9/c1784db9db0d484c8e5deeafbaac0d6ed66e165c6eb4a74fb43a5fa947d9/matplotlib-3.8.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/e5/76/94bc17eb868f8c7397f8fdfdeae7661c1b9a35f3a7219da308596e8c252a/contourpy-1.1.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/95/b6/9a5133deb5838c4dbe3ea27e8dba123622aa5112d43a079e9587636b4faf/fonttools-4.42.1-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/154.1 kB ? eta -:--:--
#      -------------------------------------  153.6/154.1 kB 9.0 MB/s eta 0:00:01
#      -------------------------------------- 154.1/154.1 kB 2.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[74], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
data= pd.read_csv("dataset/TG_STAID000001.txt", skiprows=19, parse_dates=['    DATE'])
data
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %% [markdown]
# ## Showing certain columns

# %%
data[0:25]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 0       1   35381 1860-01-01     21      0
# 1       1   35381 1860-01-02     46      0
# 2       1   35381 1860-01-03     31      0
# 3       1   35381 1860-01-04     37      0
# 4       1   35381 1860-01-05     31      0
# 5       1   35381 1860-01-06     16      0
# 6       1   35381 1860-01-07      5      0
# 7       1   35381 1860-01-08    -27      0
# 8       1   35381 1860-01-09     -4      0
# 9       1   35381 1860-01-10    -17      0
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0
# 20      1   35381 1860-01-21    -11      0
# ...

# %%
data['   TG']
# Out:
# 0          21
# 1          46
# 2          31
# 3          37
# 4          31
#          ...
# 59316   -9999
# 59317   -9999
# 59318   -9999
# 59319   -9999
# 59320   -9999
# Name:    TG, Length: 59321, dtype: int64

# %%
data.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
data[[' SOUID', '    DATE','   TG']][0:25]
# Out:
#      SOUID       DATE     TG
# 0    35381 1860-01-01     21
# 1    35381 1860-01-02     46
# 2    35381 1860-01-03     31
# 3    35381 1860-01-04     37
# 4    35381 1860-01-05     31
# 5    35381 1860-01-06     16
# 6    35381 1860-01-07      5
# 7    35381 1860-01-08    -27
# 8    35381 1860-01-09     -4
# 9    35381 1860-01-10    -17
# 10   35381 1860-01-11     -5
# 11   35381 1860-01-12    -18
# 12   35381 1860-01-13    -27
# 13   35381 1860-01-14    -26
# 14   35381 1860-01-15    -37
# 15   35381 1860-01-16     -9
# 16   35381 1860-01-17      7
# 17   35381 1860-01-18     -6
# 18   35381 1860-01-19    -16
# 19   35381 1860-01-20    -19
# 20   35381 1860-01-21    -11
# 21   35381 1860-01-22     -1
# 22   35381 1860-01-23      2
# 23   35381 1860-01-24      7
# 24   35381 1860-01-25     10

# %% [markdown]
# ## Simple statistical calculations

# %%
data['   TG'].mean()
# Out:
# -991.1500649011311

# %%
data.loc[data['   TG']!=-9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
data.loc[data['   TG']!=-9999].mean()
# Out:
# STAID                                 1.0
#  SOUID                       35381.009943
#     DATE    1932-12-25 01:56:39.468956672
#    TG                           63.607875
#  Q_TG                            0.000056
# dtype: object

# %%
data.loc[data['   TG']!=-9999]['   TG'].mean()
# Out:
# 63.607875261284676

# %%
data.loc[data['   TG']!=-9999]['   TG'].max()/10
# Out:
# 26.2

# %%
data.loc[data['   TG']!=-9999]['   TG'].min()/10
# Out:
# -28.8

# %%
data['   TG'].hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 data['   TG'].hist()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:124, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      43 def hist_series(
#      44     self,
#      45     by=None,
#    (...)
#      56     **kwargs,
#      57 ):
#      58     """
#      59     Draw histogram of the input series using matplotlib.
#      60
#    (...)
#     122         >>> hist = ser.groupby(level=0).hist()
#     123     """
# --> 124     plot_backend = _get_plot_backend(backend)
#     125     return plot_backend.hist_series(
#     126         self,
#     127         by=by,
#    (...)
#     137         **kwargs,
#     138     )
#
# ...
