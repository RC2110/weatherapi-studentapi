# %%
import pandas as pd

# %%
df= pd.read_csv("dataset/TG_STAID000001.txt", skiprows=20, parse_dates=['    DATE'])

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
df[0:25]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 0       1   35381 1860-01-01     21      0
# 1       1   35381 1860-01-02     46      0
# 2       1   35381 1860-01-03     31      0
# 3       1   35381 1860-01-04     37      0
# 4       1   35381 1860-01-05     31      0
# 5       1   35381 1860-01-06     16      0
# 6       1   35381 1860-01-07      5      0
# 7       1   35381 1860-01-08    -27      0
# 8       1   35381 1860-01-09     -4      0
# 9       1   35381 1860-01-10    -17      0
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0
# 20      1   35381 1860-01-21    -11      0
# 21      1   35381 1860-01-22     -1      0
# 22      1   35381 1860-01-23      2      0
# 23      1   35381 1860-01-24      7      0
# 24      1   35381 1860-01-25     10      0

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
df.loc[df['   TG']!=-9999]['   TG'].mean()
# Out:
# 63.607875261284676

# %%
df.loc[df['   TG']!=-9999]['   TG'].max()
# Out:
# 262

# %%
df.loc[df['   TG']!=-9999]['   TG'].min()
# Out:
# -288

# %%
import numpy as np
df['TG']=df['   TG'].mask(df['   TG']==-9999,np.nan)

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG    TG
# 0          1   35381 1860-01-01     21      0  21.0
# 1          1   35381 1860-01-02     46      0  46.0
# 2          1   35381 1860-01-03     31      0  31.0
# 3          1   35381 1860-01-04     37      0  37.0
# 4          1   35381 1860-01-05     31      0  31.0
# ...      ...     ...        ...    ...    ...   ...
# 59316      1   35381 2022-05-27  -9999      9   NaN
# 59317      1   35381 2022-05-28  -9999      9   NaN
# 59318      1   35381 2022-05-29  -9999      9   NaN
# 59319      1   35381 2022-05-30  -9999      9   NaN
# 59320      1   35381 2022-05-31  -9999      9   NaN
#
# [59321 rows x 6 columns]

# %%
df['TG']=df['TG'] / 10

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG
# 0          1   35381 1860-01-01     21      0  2.1
# 1          1   35381 1860-01-02     46      0  4.6
# 2          1   35381 1860-01-03     31      0  3.1
# 3          1   35381 1860-01-04     37      0  3.7
# 4          1   35381 1860-01-05     31      0  3.1
# ...      ...     ...        ...    ...    ...  ...
# 59316      1   35381 2022-05-27  -9999      9  NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN
#
# [59321 rows x 6 columns]

# %%
df['Farenheit']= df['TG'] * 9/5 +32

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG', 'TG', 'Farenheit'], dtype='object')

# %%
df[[' SOUID','    DATE', 'TG']][0:25]
# Out:
#      SOUID       DATE   TG
# 0    35381 1860-01-01  2.1
# 1    35381 1860-01-02  4.6
# 2    35381 1860-01-03  3.1
# 3    35381 1860-01-04  3.7
# 4    35381 1860-01-05  3.1
# 5    35381 1860-01-06  1.6
# 6    35381 1860-01-07  0.5
# 7    35381 1860-01-08 -2.7
# 8    35381 1860-01-09 -0.4
# 9    35381 1860-01-10 -1.7
# 10   35381 1860-01-11 -0.5
# 11   35381 1860-01-12 -1.8
# 12   35381 1860-01-13 -2.7
# 13   35381 1860-01-14 -2.6
# 14   35381 1860-01-15 -3.7
# 15   35381 1860-01-16 -0.9
# 16   35381 1860-01-17  0.7
# 17   35381 1860-01-18 -0.6
# 18   35381 1860-01-19 -1.6
# 19   35381 1860-01-20 -1.9
# 20   35381 1860-01-21 -1.1
# 21   35381 1860-01-22 -0.1
# 22   35381 1860-01-23  0.2
# 23   35381 1860-01-24  0.7
# 24   35381 1860-01-25  1.0

# %%
df[0:100].plot('    DATE', 'TG', figsize=(13,3))
# Out:
# <Axes: xlabel='    DATE'>

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  Farenheit
# 0          1   35381 1860-01-01     21      0  2.1      35.78
# 1          1   35381 1860-01-02     46      0  4.6      40.28
# 2          1   35381 1860-01-03     31      0  3.1      37.58
# 3          1   35381 1860-01-04     37      0  3.7      38.66
# 4          1   35381 1860-01-05     31      0  3.1      37.58
# ...      ...     ...        ...    ...    ...  ...        ...
# 59316      1   35381 2022-05-27  -9999      9  NaN        NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN        NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN        NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN        NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN        NaN
#
# [59321 rows x 7 columns]

# %%
df.loc[df['    DATE']=="1860-01-04"]
# Out:
#    STAID   SOUID       DATE     TG   Q_TG   TG  Farenheit
# 3      1   35381 1860-01-04     37      0  3.7      38.66

# %%
df.loc[df['    DATE']=="1860-01-04"]['TG'].squeeze()
# Out:
# 3.7

# %%
df.loc[df['TG']==3.9]['    DATE'].min()
# Out:
# Timestamp('1860-04-25 00:00:00')

# %%
df.loc[df['TG']==3.9]['    DATE'].max()
# Out:
# Timestamp('2006-11-11 00:00:00')

# %%
df.loc[df['TG'] == df['TG'].max()]['    DATE'].squeeze()
# Out:
# Timestamp('1868-08-16 00:00:00')

# %%
df.iloc[6,3]
# Out:
# 5

# %%
df.loc[1]
# Out:
# STAID                          1
#  SOUID                     35381
#     DATE     1860-01-02 00:00:00
#    TG                         46
#  Q_TG                          0
# TG                           4.6
# Farenheit                  40.28
# Name: 1, dtype: object

# %%
df['TG'].hist(bins=20)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59321 entries, 0 to 59320
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STAID      59321 non-null  int64
#  1    SOUID     59321 non-null  int64
#  2       DATE   59321 non-null  datetime64[ns]
#  3      TG      59321 non-null  int64
#  4    Q_TG      59321 non-null  int64
#  5   TG         53103 non-null  float64
#  6   Farenheit  53103 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 3.2 MB

# %%
df.describe()
# Out:
#          STAID         SOUID                 DATE            TG          Q_TG  \
# count  59321.0  59321.000000                59321  59321.000000  59321.000000
# mean       1.0  35381.008901  1941-03-17 00:00:00   -991.150065      0.943426
# min        1.0  35381.000000  1860-01-01 00:00:00  -9999.000000      0.000000
# 25%        1.0  35381.000000  1900-08-09 00:00:00    -13.000000      0.000000
# 50%        1.0  35381.000000  1941-03-17 00:00:00     46.000000      0.000000
# 75%        1.0  35381.000000  1981-10-23 00:00:00    123.000000      0.000000
# max        1.0  35405.000000  2022-05-31 00:00:00    262.000000      9.000000
# std        0.0      0.462106                  NaN   3083.274487      2.756902
#
#                  TG     Farenheit
# count  53103.000000  53103.000000
# mean       6.360788     43.449418
# min      -28.800000    -19.840000
# 25%        0.700000     33.260000
# 50%        6.100000     42.980000
# 75%       12.900000     55.220000
# max       26.200000     79.160000
# std        7.709162     13.876491
